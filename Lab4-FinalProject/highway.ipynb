# %%
from ultralytics import YOLO

# 1. 載入模型
model = YOLO("best.pt")

# 2. 影片推論
results = model.predict(
    source="videoTest",   # 直接指定資料夾路徑
    save=True,            # 將推論後的影片儲存
    conf=0.3,             # 信心閾值
    show=False            # 是否在視窗中即時顯示
)

# 結果影片會存到 runs/detect/predict 目錄下
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/3 (frame 1/87) c:\Users\Brian\Desktop\\2025_AIoT_3.4_Team2\Lab4-FinalProject\videoTest\Tw-Highway-1.mp4: 384x640 6 cars, 37.5ms
# video 1/3 (frame 2/87) c:\Users\Brian\Desktop\\2025_AIoT_3.4_Team2\Lab4-FinalProject\videoTest\Tw-Highway-1.mp4: 384x640 7 cars, 7.6ms
# video 1/3 (frame 3/87) c:\Users\Brian\Desktop\\2025_AIoT_3.4_Team2\Lab4-FinalProject\videoTest\Tw-Highway-1.mp4: 384x640 7 cars, 11.0ms
# ...
